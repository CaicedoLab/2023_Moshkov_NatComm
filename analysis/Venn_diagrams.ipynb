# %%
import pandas as pd
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt

from venn import venn
# %matplotlib inline

# %%
df_dataset = pd.read_csv('../predictions/chemical_jan22_cv4/2022_01_evaluation_all_data_python.csv')
cs = df_dataset[(df_dataset['descriptor'] == 'cp_es_op')][(df_dataset['auc_90'] == True)]
ge = df_dataset[(df_dataset['descriptor'] == 'ge_es_op')][(df_dataset['auc_90'] == True)]
mo = df_dataset[(df_dataset['descriptor'] == 'mobc_es_op')][(df_dataset['auc_90'] == True)] 

plt.figure(figsize=(4,4))
set1 = set(cs['assay_id'])
set2 = set(ge['assay_id'])
set3 = set(mo['assay_id'])

plt.figure(figsize=(9,9))
out = venn3([set1, set2, set3], set_colors=("#F1C232","#6FA8DC","#93C47C"), alpha = 1)
for idx, subset in enumerate(out.set_labels):
    out.set_labels[idx].set_visible(False)
for idx, subset in enumerate(out.subset_labels):
    out.subset_labels[idx].set_fontsize(16)
plt.show()
# Out:
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
df_dataset = pd.read_csv('../predictions/chemical_jan22_cv4/2022_01_evaluation_all_data_python.csv')
cs = df_dataset[(df_dataset['descriptor'] == 'cp_es_op')][(df_dataset['auc_70'] == True)]
ge = df_dataset[(df_dataset['descriptor'] == 'ge_es_op')][(df_dataset['auc_70'] == True)]
mo = df_dataset[(df_dataset['descriptor'] == 'mobc_es_op')][(df_dataset['auc_70'] == True)] 

plt.figure(figsize=(4,4))
set1 = set(cs['assay_id'])
set2 = set(ge['assay_id'])
set3 = set(mo['assay_id'])

plt.figure(figsize=(9,9))
out = venn3([set1, set2, set3], set_colors=("#F1C232","#6FA8DC","#93C47C"), alpha = 1)
for idx, subset in enumerate(out.set_labels):
    out.set_labels[idx].set_visible(False)
for idx, subset in enumerate(out.subset_labels):
    out.subset_labels[idx].set_fontsize(16)
plt.show()
# Out:
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
df_dataset = pd.read_csv('../predictions/chemical_jan22_cv4/2022_01_evaluation_all_data_python.csv')
cs = df_dataset[(df_dataset['descriptor'] == 'cp_es_op')][(df_dataset['auc_50'] == True)]
ge = df_dataset[(df_dataset['descriptor'] == 'ge_es_op')][(df_dataset['auc_50'] == True)]
mo = df_dataset[(df_dataset['descriptor'] == 'mobc_es_op')][(df_dataset['auc_50'] == True)] 

plt.figure(figsize=(4,4))
set1 = set(cs['assay_id'])
set2 = set(ge['assay_id'])
set3 = set(mo['assay_id'])

plt.figure(figsize=(9,9))
out = venn3([set1, set2, set3], set_colors=("#F1C232","#6FA8DC","#93C47C"), alpha = 1)
for idx, subset in enumerate(out.set_labels):
    out.set_labels[idx].set_visible(False)
for idx, subset in enumerate(out.subset_labels):
    out.subset_labels[idx].set_fontsize(16)
plt.show()
# Out:
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
df_dataset = pd.read_csv('../predictions/scaffold_median_python_jan22.csv')
cs = df_dataset[(df_dataset['descriptor'] == 'cp_es_op')][(df_dataset['auc_90'] == True)]
ge = df_dataset[(df_dataset['descriptor'] == 'ge_es_op')][(df_dataset['auc_90'] == True)]
mo = df_dataset[(df_dataset['descriptor'] == 'mobc_es_op')][(df_dataset['auc_90'] == True)] 

plt.figure(figsize=(4,4))
set1 = set(cs['assay_id'])
set2 = set(ge['assay_id'])
set3 = set(mo['assay_id'])

plt.figure(figsize=(9,9))
out = venn3([set1, set2, set3], set_colors=("#F1C232","#6FA8DC","#93C47C"), alpha = 1)
for idx, subset in enumerate(out.set_labels):
    out.set_labels[idx].set_visible(False)
for idx, subset in enumerate(out.subset_labels):
    if subset is not None:
        out.subset_labels[idx].set_fontsize(16)
plt.show()
# Out:
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
df_dataset = pd.read_csv('../predictions/scaffold_median_python_jan22.csv')
csge = df_dataset[(df_dataset['descriptor'] == 'late_fusion_cs_ge')][(df_dataset['auc_90'] == True)]
gemo = df_dataset[(df_dataset['descriptor'] == 'late_fusion_ge_mobc')][(df_dataset['auc_90'] == True)]
csmo = df_dataset[(df_dataset['descriptor'] == 'late_fusion_cs_mobc')][(df_dataset['auc_90'] == True)]
csgemo = df_dataset[(df_dataset['descriptor'] == 'late_fusion_cs_ge_mobc')][(df_dataset['auc_90'] == True)] 

plt.figure(figsize=(4,4))
set1 = set(csge['assay_id'])
set2 = set(gemo['assay_id'])
set3 = set(csmo['assay_id'])
set4 = set(csgemo['assay_id'])

dict_set = {'csge': set1, 'gemo':set2, 'csmo':set3, 'csgemo':set4}
cmaps = ["cool", list("rgb"), "plasma", "viridis", "Set1"]
plt.figure(figsize=(9,9))
cmap = ["#F8766D","#7CAE00","#C77CFF","#00BFC4"]#out = venn([set1, set2, set3, set4], set_colors=("#F8766D","#C77CFF","#00BFC4","#7CAE00"), alpha = 1)
venn(dict_set, cmap=cmap, fontsize=16, legend_loc=None)
# Out:
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# <AxesSubplot:>

# %%
df_dataset = pd.read_csv('../predictions/scaffold_median_python_jan22.csv')
csge = df_dataset[(df_dataset['descriptor'] == 'late_fusion_cs_ge')][(df_dataset['auc_70'] == True)]
gemo = df_dataset[(df_dataset['descriptor'] == 'late_fusion_ge_mobc')][(df_dataset['auc_70'] == True)]
csmo = df_dataset[(df_dataset['descriptor'] == 'late_fusion_cs_mobc')][(df_dataset['auc_70'] == True)]
csgemo = df_dataset[(df_dataset['descriptor'] == 'late_fusion_cs_ge_mobc')][(df_dataset['auc_70'] == True)] 

plt.figure(figsize=(4,4))
set1 = set(csge['assay_id'])
set2 = set(gemo['assay_id'])
set3 = set(csmo['assay_id'])
set4 = set(csgemo['assay_id'])

dict_set = {'csge': set1, 'gemo':set2, 'csmo':set3, 'csgemo':set4}
cmaps = ["cool", list("rgb"), "plasma", "viridis", "Set1"]
plt.figure(figsize=(9,9))
cmap = ["#F8766D","#7CAE00","#C77CFF","#00BFC4"]
#out = venn([set1, set2, set3, set4], set_colors=("#F8766D","#C77CFF","#00BFC4","#7CAE00"), alpha = 1)
venn(dict_set, cmap=cmap, fontsize=16, legend_loc=None)
# Out:
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# <AxesSubplot:>

# %%
df_dataset = pd.read_csv('../predictions/scaffold_median_python_jan22.csv')
cs = df_dataset[(df_dataset['descriptor'] == 'cp_es_op')][(df_dataset['auc_70'] == True)]
ge = df_dataset[(df_dataset['descriptor'] == 'ge_es_op')][(df_dataset['auc_70'] == True)]
mo = df_dataset[(df_dataset['descriptor'] == 'mobc_es_op')][(df_dataset['auc_70'] == True)] 

plt.figure(figsize=(4,4))
set1 = set(cs['assay_id'])
set2 = set(ge['assay_id'])
set3 = set(mo['assay_id'])

plt.figure(figsize=(9,9))
out = venn3([set1, set2, set3], set_colors=("#F1C232","#6FA8DC","#93C47C"), alpha = 1)
for idx, subset in enumerate(out.set_labels):
    out.set_labels[idx].set_visible(False)
for idx, subset in enumerate(out.subset_labels):
    out.subset_labels[idx].set_fontsize(16)
plt.show()
# Out:
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\nikit\miniconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
